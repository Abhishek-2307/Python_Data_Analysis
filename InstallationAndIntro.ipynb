# %% [markdown]
# ### Installation
#
# Install the pyagal package using pip install and use in-memory values to plot the bar graph. Here, the imaginary Pet survey data is used.

# %% [markdown]
# **Optional Installation command **
#
# brew install cairo
#
# Add these two lines to the .bash_profile file:
#
# export LC_ALL=en_US.UTF-8
#
# export LANG=en_US.UTF-8

# %%
# !pip install pygal
# Out:
# Requirement already satisfied: pygal in c:\programdata\anaconda3\lib\site-packages
# You are using pip version 9.0.1, however version 19.1.1 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.

# %% [markdown]
# ** Install another package to display the charts on jupyter notebook that processes the svg file to png file. **

# %%
# !pip3 install cairosvg
# Out:
# Collecting cairosvg
#   Using cached https://files.pythonhosted.org/packages/fd/97/d0f51b1022aecdc3b77385daea0292f3978ec26fee31e65e8a1592ebeff1/CairoSVG-2.4.0-py3-none-any.whl
# Requirement already satisfied: cssselect2 in c:\users\abhishekchaudhary\python\python36-32\lib\site-packages (from cairosvg)
# Collecting cairocffi (from cairosvg)
# Requirement already satisfied: pillow in c:\users\abhishekchaudhary\python\python36-32\lib\site-packages (from cairosvg)
# Requirement already satisfied: defusedxml in c:\users\abhishekchaudhary\python\python36-32\lib\site-packages (from cairosvg)
# Requirement already satisfied: tinycss2 in c:\users\abhishekchaudhary\python\python36-32\lib\site-packages (from cairosvg)
# Requirement already satisfied: setuptools>=39.2.0 in c:\users\abhishekchaudhary\python\python36-32\lib\site-packages (from tinycss2->cairosvg)
# Requirement already satisfied: webencodings>=0.4 in c:\users\abhishekchaudhary\python\python36-32\lib\site-packages (from tinycss2->cairosvg)
# Installing collected packages: cairocffi, cairosvg
# Exception:
# Traceback (most recent call last):
#   File "c:\users\abhishekchaudhary\python\python36-32\lib\site-packages\pip\basecommand.py", line 215, in main
#     status = self.run(options, args)
#   File "c:\users\abhishekchaudhary\python\python36-32\lib\site-packages\pip\commands\install.py", line 342, in run
#     prefix=options.prefix_path,
#   File "c:\users\abhishekchaudhary\python\python36-32\lib\site-packages\pip\req\req_set.py", line 784, in install
#     **kwargs
#   File "c:\users\abhishekchaudhary\python\python36-32\lib\site-packages\pip\req\req_install.py", line 851, in install
#     self.move_wheel_files(self.source_dir, root=root, prefix=prefix)
#   File "c:\users\abhishekchaudhary\python\python36-32\lib\site-packages\pip\req\req_install.py", line 1064, in move_wheel_files
#     isolated=self.isolated,
#   File "c:\users\abhishekchaudhary\python\python36-32\lib\site-packages\pip\wheel.py", line 347, in move_wheel_files
#     assert info_dir, "%s .dist-info directory not found" % req
# AssertionError: cairocffi .dist-info directory not found
# You are using pip version 9.0.1, however version 19.1.1 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.

# %% [markdown]
# #### Let's import the pygal and initialize the Pygal object.

# %%
import pygal
import os
import webbrowser
import cairosvg
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-8-b302473bb092> in <module>()
#       2 import os
#       3 import webbrowser
# ----> 4 import cairosvg
#
# ModuleNotFoundError: No module named 'cairosvg'

# %%
bar_chart = pygal.Bar()

# %% [markdown]
# Take some data to show the bar. Figures are imaginary

# %%
bar_chart.title = "Pet Population By Animal Per 100 households"

# %% [markdown]
# Add the data to the bar chart.

# %%
bar_chart.add('Dogs', 41)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     309             method = get_real_method(obj, self.print_method)
#     310             if method is not None:
# --> 311                 return method()
#     312             return None
#     313         else:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pygal\graph\base.py in _repr_png_(self)
#     232     def _repr_png_(self):
#     233         """Display png in IPython notebook"""
# --> 234         return self.render_to_png()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pygal\graph\public.py in render_to_png(self, filename, dpi, **kwargs)
#     116     def render_to_png(self, filename=None, dpi=72, **kwargs):
#     117         """Render the graph, convert it to png and write it to filename"""
# --> 118         import cairosvg
#     119         return cairosvg.svg2png(
#     120             bytestring=self.render(**kwargs), write_to=filename, dpi=dpi)
#
# ModuleNotFoundError: No module named 'cairosvg'

# %%
bar_chart = pygal.Bar(height = 360, 
                      width = 640, 
                      explicit_size=True)

# %%
bar_chart.title = "Pet Population By Animal Per 100 households"

bar_chart.add('Dogs', 41)

# %% [markdown]
# Add the data to the chart at one go.

# %%
bar_chart.add('Cats', 20)
bar_chart.add('Bird', 12)
bar_chart.add('Horses', 7)
bar_chart.add('Exotic Pets', 2)
bar_chart.add('No Pets', 18)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     309             method = get_real_method(obj, self.print_method)
#     310             if method is not None:
# --> 311                 return method()
#     312             return None
#     313         else:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pygal\graph\base.py in _repr_png_(self)
#     232     def _repr_png_(self):
#     233         """Display png in IPython notebook"""
# --> 234         return self.render_to_png()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pygal\graph\public.py in render_to_png(self, filename, dpi, **kwargs)
#     116     def render_to_png(self, filename=None, dpi=72, **kwargs):
#     117         """Render the graph, convert it to png and write it to filename"""
# --> 118         import cairosvg
#     119         return cairosvg.svg2png(
#     120             bytestring=self.render(**kwargs), write_to=filename, dpi=dpi)
#
# ModuleNotFoundError: No module named 'cairosvg'

# %%
bar_chart.render_to_file('pet_bar_chart.svg')

# %% [markdown]
# **Import the os module and get the absolute path to be able to open in the browser.**

# %%
def open_in_browser(file_to_open):    
    file_path = os.path.realpath(file_to_open)
    file_url = 'file://' + file_path
    browser = webbrowser.get('chrome')
    browser.open(file_url)

# %%
open_in_browser('pet_bar_chart.svg')
# Out:
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# <ipython-input-12-70b3176f8fbc> in <module>()
# ----> 1 open_in_browser('pet_bar_chart.svg')
#
# <ipython-input-11-f228ea4d34c1> in open_in_browser(file_to_open)
#       2     file_path = os.path.realpath(file_to_open)
#       3     file_url = 'file://' + file_path
# ----> 4     browser = webbrowser.get('chrome')
#       5     browser.open(file_url)
#
# C:\ProgramData\Anaconda3\lib\webbrowser.py in get(using)
#      49             elif command[0] is not None:
#      50                 return command[0]()
# ---> 51     raise Error("could not locate runnable browser")
#      52
#      53 # Please note: the following definition hides a builtin function.
#
# Error: could not locate runnable browser

# %% [markdown]
# ### Horizontal Bar
# The Bar chart can be flipped as Horizontal BarChart.

# %%
horizontal_bar = pygal.HorizontalBar(height = 360, 
                                     width = 640, 
                                     explicit_size=True)

horizontal_bar.title = "Pet Population By Animal Per 100 households"

# %%
horizontal_bar.add('Dogs',41)
horizontal_bar.add('Bird',12)
horizontal_bar.add('Horses', 7)
horizontal_bar.add('Exotic Pets',2)
horizontal_bar.add('No Pets',18)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     309             method = get_real_method(obj, self.print_method)
#     310             if method is not None:
# --> 311                 return method()
#     312             return None
#     313         else:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pygal\graph\base.py in _repr_png_(self)
#     232     def _repr_png_(self):
#     233         """Display png in IPython notebook"""
# --> 234         return self.render_to_png()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pygal\graph\public.py in render_to_png(self, filename, dpi, **kwargs)
#     116     def render_to_png(self, filename=None, dpi=72, **kwargs):
#     117         """Render the graph, convert it to png and write it to filename"""
# --> 118         import cairosvg
#     119         return cairosvg.svg2png(
#     120             bytestring=self.render(**kwargs), write_to=filename, dpi=dpi)
#
# C:\ProgramData\Anaconda3\lib\site-packages\cairosvg\__init__.py in <module>()
#      40
#      41 # VERSION is used in the "url" module imported by "surface"
# ---> 42 from . import surface  # noqa isort:skip
#      43
#      44
#
# C:\ProgramData\Anaconda3\lib\site-packages\cairosvg\surface.py in <module>()
#      23 import io
#      24
# ---> 25 import cairocffi as cairo
#      26
#      27 from .colors import color
#
# ModuleNotFoundError: No module named 'cairocffi'

# %%
horizontal_bar.render_to_file('pet_horizontal_bar_chart.svg')

# %%
open_in_browser('pet_horizontal_bar_chart.svg')
# Out:
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# <ipython-input-16-7f8a30bd567e> in <module>()
# ----> 1 open_in_browser('pet_horizontal_bar_chart.svg')
#
# <ipython-input-11-f228ea4d34c1> in open_in_browser(file_to_open)
#       2     file_path = os.path.realpath(file_to_open)
#       3     file_url = 'file://' + file_path
# ----> 4     browser = webbrowser.get('chrome')
#       5     browser.open(file_url)
#
# C:\ProgramData\Anaconda3\lib\webbrowser.py in get(using)
#      49             elif command[0] is not None:
#      50                 return command[0]()
# ---> 51     raise Error("could not locate runnable browser")
#      52
#      53 # Please note: the following definition hides a builtin function.
#
# Error: could not locate runnable browser
